# %% [markdown]
# | <h1> Hands-on Activity 3.1 </h1> | <h1> Data Analysis </h1> |
# |--- | --- |
# Name: Buan, Danilo Jr. G. <br>
# Course and Section: CPE019S3 <br>
# Date Submitted: 01/24/23 <br>
# Instructor: Engr. Roman M. Richard
# Date Performed: 02/07/24

# %% [markdown]
# #Part 1: The Dataset
#
# Step 1: Loading the Dataset from a file

# %%
import pandas as pd
brainFile = '/content/brainsize.txt'
brainFrame = pd.read_csv(brainFile, sep = '\t')

# %% [markdown]
# Step 2: Verifying the dataframe.

# %%
brainFrame.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0  Female   133  132  124   118.0    64.5     816932
# 1    Male   140  150  124     NaN    72.5    1001121
# 2    Male   139  123  150   143.0    73.3    1038437
# 3    Male   133  129  128   172.0    68.8     965353
# 4  Female   137  132  134   147.0    65.0     951545

# %% [markdown]
# Observation: For this part, it helped me understand how to import a csv and how it can be displayed with proper format.

# %% [markdown]
# #Part 2: Scatterplot Graphs and Correlatable Variables
#
# Step 1: The pandas describe() method

# %%
brainFrame.describe()
# Out:
#              FSIQ         VIQ        PIQ      Weight     Height     MRI_Count
# count   40.000000   40.000000   40.00000   38.000000  39.000000  4.000000e+01
# mean   113.450000  112.350000  111.02500  151.052632  68.525641  9.087550e+05
# std     24.082071   23.616107   22.47105   23.478509   3.994649  7.228205e+04
# min     77.000000   71.000000   72.00000  106.000000  62.000000  7.906190e+05
# 25%     89.750000   90.000000   88.25000  135.250000  66.000000  8.559185e+05
# 50%    116.500000  113.000000  115.00000  146.500000  68.000000  9.053990e+05
# 75%    135.500000  129.750000  128.00000  172.000000  70.500000  9.500780e+05
# max    144.000000  150.000000  150.00000  192.000000  77.000000  1.079549e+06

# %% [markdown]
# Step 2: Scatterplot graphs
#
# a. Load the required modules.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# b. Separate the data.

# %%
menDf = brainFrame[(brainFrame.Gender == 'Male')]
womenDf = brainFrame[(brainFrame.Gender == 'Female')]

# %% [markdown]
# c. Plot the graphs

# %%
menMeanSmarts = menDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(menMeanSmarts, menDf["MRI_Count"])
plt.show()
# %matplotlib inline

# %%
womenMeanSmarts = womenDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(womenMeanSmarts, womenDf["MRI_Count"])
plt.show()
# %matplotlib inline

# %% [markdown]
# Observation: With the modules used such as pandas, numpy and matplotlib, we can manipulate the data however we want.

# %% [markdown]
# #Part 3: Calculating Correlation with Python
#
# <br>
#
# Step 1: Calculate correlation against brainFrame.

# %%
brainFrame.corr(method='pearson')
# Out:
# <ipython-input-16-4d3089cc6357>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   brainFrame.corr(method='pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.946639  0.934125 -0.051483 -0.086002   0.357641
# VIQ        0.946639  1.000000  0.778135 -0.076088 -0.071068   0.337478
# PIQ        0.934125  0.778135  1.000000  0.002512 -0.076723   0.386817
# Weight    -0.051483 -0.076088  0.002512  1.000000  0.699614   0.513378
# Height    -0.086002 -0.071068 -0.076723  0.699614  1.000000   0.601712
# MRI_Count  0.357641  0.337478  0.386817  0.513378  0.601712   1.000000

# %% [markdown]
#  - Notice at the left-to-right diagonal in the correlation table generated above. Why is the diagonal filled with 1s? Is that a coincidence? Explain
#
# This just shows that when comparing a variable to itself, it should be perfect since it represents a perfect relationship.
#
#
#  - Still looking at the correlation table above, notice that the values are mirrored; values below the 1
# diagonal have a mirrored counterpart above the 1 diagonal. Is that a coincidence? Explain.
#
# Again, it is not a coincidence because it is by design and a mathematical property of correlation.

# %%
womenDf.corr(method = 'pearson')
# Out:
# <ipython-input-17-f3b71eba93ce>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   womenDf.corr(method = 'pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.955717  0.939382  0.038192 -0.059011   0.325697
# VIQ        0.955717  1.000000  0.802652 -0.021889 -0.146453   0.254933
# PIQ        0.939382  0.802652  1.000000  0.113901 -0.001242   0.396157
# Weight     0.038192 -0.021889  0.113901  1.000000  0.552357   0.446271
# Height    -0.059011 -0.146453 -0.001242  0.552357  1.000000   0.174541
# MRI_Count  0.325697  0.254933  0.396157  0.446271  0.174541   1.000000

# %%
menDf.corr(method = 'pearson')

# %% [markdown]
# Observation: For this part, I have learned how to use the pearson correlation for the data that we are manipulating, and also I have learned how to separate categories such as the genders.

# %% [markdown]
# #Part 4: Visualizing
# <br>
# Step 1: Install Seaborn.

# %%
# !pip install seaborn

# %% [markdown]
# Step 2: Plot the correlation heatmap

# %%
import seaborn as sns

wcorr = womenDf.corr()
sns.heatmap(wcorr)
#plt.savefig('attribute_correlation.png', tight_layout=True)
# Out:
# <ipython-input-19-61c8505a0e17>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   wcorr = womenDf.corr()
# <Axes: >

# %%
mcorr = menDf.corr()
sns.heatmap(mcorr)
#plt.savefig('attribute_correlation.png', tight_layout=True)
# Out:
# <ipython-input-20-f5a978bb92fd>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mcorr = menDf.corr()
# <Axes: >

# %% [markdown]
# - Many variable pairs present correlation close to zero. What does that mean?
#
# It means that the relationship between the pairs is weak or non-existent.
#
# - Why separate the genders?
#
# It can help idenfify the differences and similarities of the data of both genders and to also identify different patterns among the two.
#
# - What variables have stronger correlation with brain size (MRI_Count)? Is that expected? Explain.

# %% [markdown]
# Observation: For this part, I have learned how to visualize the data by using the seaborn module. It helped me understand more about the relationship between different categories inside the dataset.

# %% [markdown]
# #Supplementary Activity

# %% [markdown]
# The real-world dataset I have used is from kaggle and it is about medical appointments from Brazil and is focused on whether or not patients show up for their appointments.

# %%
import pandas as pd

medFile = '/content/md.csv'
medFrame = pd.read_csv(medFile)
medFrame.head(50)
# Out:
#        PatientId  AppointmentID Gender          ScheduledDay  \
# 0   2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1   5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2   4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3   8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4   8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# 5   9.598513e+13        5626772      F  2016-04-27T08:36:51Z
# 6   7.336882e+14        5630279      F  2016-04-27T15:05:12Z
# 7   3.449833e+12        5630575      F  2016-04-27T15:39:58Z
# 8   5.639473e+13        5638447      F  2016-04-29T08:02:16Z
# 9   7.812456e+13        5629123      F  2016-04-27T12:48:25Z
# 10  7.345362e+14        5630213      F  2016-04-27T14:58:11Z
# 11  7.542951e+12        5620163      M  2016-04-26T08:44:12Z
# 12  5.666548e+14        5634718      F  2016-04-28T11:33:51Z
# 13  9.113946e+14        5636249      M  2016-04-28T14:52:07Z
# ...

# %% [markdown]
# Observation: For this dataset, it would consume the whole webpage if I would show it whole, so I just set it to 50. As shown above, we were able to have an idea about what the categories are and some values inside.

# %%
medFrame.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# Observation: Using the describe function helps me test the validity of the values in this dataset.

# %%
m_drop = medFrame.drop("PatientId", axis = 1)
m_drop.head(50)
# Out:
#     AppointmentID Gender          ScheduledDay        AppointmentDay  Age  \
# 0         5642903      F  2016-04-29T18:38:08Z  2016-04-29T00:00:00Z   62
# 1         5642503      M  2016-04-29T16:08:27Z  2016-04-29T00:00:00Z   56
# 2         5642549      F  2016-04-29T16:19:04Z  2016-04-29T00:00:00Z   62
# 3         5642828      F  2016-04-29T17:29:31Z  2016-04-29T00:00:00Z    8
# 4         5642494      F  2016-04-29T16:07:23Z  2016-04-29T00:00:00Z   56
# 5         5626772      F  2016-04-27T08:36:51Z  2016-04-29T00:00:00Z   76
# 6         5630279      F  2016-04-27T15:05:12Z  2016-04-29T00:00:00Z   23
# 7         5630575      F  2016-04-27T15:39:58Z  2016-04-29T00:00:00Z   39
# 8         5638447      F  2016-04-29T08:02:16Z  2016-04-29T00:00:00Z   21
# 9         5629123      F  2016-04-27T12:48:25Z  2016-04-29T00:00:00Z   19
# 10        5630213      F  2016-04-27T14:58:11Z  2016-04-29T00:00:00Z   30
# 11        5620163      M  2016-04-26T08:44:12Z  2016-04-29T00:00:00Z   29
# ...

# %% [markdown]
# Observation: Since the PatientId is not very important for what I am going to do with this dataset, I have dropped it using the drop() function.

# %%
menMed = m_drop[(m_drop.Gender == 'M')]
femMed = m_drop[(m_drop.Gender == 'F')]

menMeanApp = menMed[["SMS_received"]].mean(axis = 1)
plt.scatter(menMeanApp, menMed["Age"])
plt.show()
# %matplotlib inline

# %%
femMeanApp = femMed[["SMS_received"]].mean(axis = 1)
plt.scatter(femMeanApp, femMed["Age"])
plt.show()
# %matplotlib inline

# %% [markdown]
# Observation: Since the dataset I have gathered mostly have values of 0s and 1s, there is no other values to plot. And for the age, it has varied from ages 0-100 whether they have received an sms for an appointment or not. For the females however, there is a slight change towards the output since the maximum age for women is up to 120 helping us identify that there is a slight difference between the two.

# %%
m_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   AppointmentID   110527 non-null  int64
#  1   Gender          110527 non-null  object
#  2   ScheduledDay    110527 non-null  object
#  3   AppointmentDay  110527 non-null  object
#  4   Age             110527 non-null  int64
#  5   Neighbourhood   110527 non-null  object
#  6   Scholarship     110527 non-null  int64
#  7   Hipertension    110527 non-null  int64
#  8   Diabetes        110527 non-null  int64
#  9   Alcoholism      110527 non-null  int64
#  10  Handcap         110527 non-null  int64
#  11  SMS_received    110527 non-null  int64
#  12  No-show         110527 non-null  object
# dtypes: int64(8), object(5)
# memory usage: 11.0+ MB

# %% [markdown]
# Observation: By using the info() function, it can help us understand the values being used inside the categories such as the 12th column, at first I thought it was a boolean type of input but it wasn't, it was an object type.

# %%
m_drop.corr(method = 'pearson')
# Out:
# <ipython-input-34-3f806fb12ea8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   m_drop.corr(method = 'pearson')
#                AppointmentID       Age  Scholarship  Hipertension  Diabetes  \
# AppointmentID       1.000000 -0.019126     0.022615      0.012752  0.022628
# Age                -0.019126  1.000000    -0.092457      0.504586  0.292391
# Scholarship         0.022615 -0.092457     1.000000     -0.019729 -0.024894
# Hipertension        0.012752  0.504586    -0.019729      1.000000  0.433086
# Diabetes            0.022628  0.292391    -0.024894      0.433086  1.000000
# Alcoholism          0.032944  0.095811     0.035022      0.087971  0.018474
# Handcap             0.014106  0.078033    -0.008586      0.080083  0.057530
# SMS_received       -0.256618  0.012643     0.001194     -0.006267 -0.014550
#
# ...

# %% [markdown]
# Observation: As seen in the data above, we can identify the different relationship among the categories and identifying who has the most strongest and the weakest relationship.

# %%
mcorr = m_drop.corr()
sns.heatmap(mcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-36-c9090ad95873>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mcorr = m_drop.corr()
# <Axes: >

# %% [markdown]
# Observation: As seen on the data above, I have identified that there is a lot of irrelevant data meaning that this is a very good example of poor quality data.

# %% [markdown]
# #Conclusion, Observation and Analysis
#
# **Conclusion**
# - After perfoming this activity, I have concluded that having the right dataset can help you do data analysis without a problem. Since the data that I have gathered has poor quality, it really gave me a hard time to perform exploratory and statistical analysis.
#
# **Observation**
# - What I have observed is that there is a lot of functions that can still be done to analyzing data but unfortunately, it cannot be done with the dataset that I am using so maybe next time I can perform this with a dataset that is proper.
#
# **Analysis**
# - Understanding the values after performing the different functions to analysis is very important in having an idea about the correlation of the different categories with each other.
